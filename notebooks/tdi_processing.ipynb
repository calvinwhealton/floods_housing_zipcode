# %% [markdown]
# # Work for TDI project
# _Calvin Whealton_

# %%
import numpy as np
import pandas as pd
import geopandas as geopd
import os
import requests

# %% [markdown]
# ## Housing Data
# Loading a housing datasets from Realtor.com. There is historical and current data and also a historical housing hotness index.

# %%
data_historical = pd.read_csv('https://econdata.s3-us-west-2.amazonaws.com/Reports/Core/RDC_Inventory_Core_Metrics_Zip_History.csv')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (0,1,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data_historical.shape[0]
# Out:
# 764087

# %%
data_historical.head()
# Out:
#   month_date_yyyymm postal_code             zip_name flag  \
# 0            202006       72202      little rock, ar    *
# 1            202006        8826     glen gardner, nj    *
# 2            202006       39110          madison, ms    *
# 3            202006       33315  fort lauderdale, fl  NaN
# 4            202006       85028          phoenix, az    *
#
#    median_listing_price  median_listing_price_mm  median_listing_price_yy  \
# 0              220050.0                  -0.0443                  -0.0317
# 1              420000.0                   0.0001                      NaN
# 2              439500.0                   0.0267                   0.0986
# 3              414999.5                   0.0400                   0.1431
# 4              559500.0                   0.2031                      NaN
#
#    active_listing_count  active_listing_count_mm  active_listing_count_yy  \
# 0                  68.0                   0.0625                      NaN
# ...

# %%
len(data_historical['postal_code'].unique())
# Out:
# 30223

# %%
data_historical.tail()
# Out:
#                                         month_date_yyyymm  \
# 764082                                             201607
# 764083                                             201607
# 764084                                             201607
# 764085                                             201607
# 764086  * year-over-year figures impacted in this area...
#
#                                               postal_code           zip_name  \
# 764082                                              30316        atlanta, ga
# 764083                                              60013           cary, il
# 764084                                              74857        newalla, ok
# 764085                                              70357  golden meadow, la
# 764086   please contact economics@realtor.com for more...                NaN
#
#        flag  median_listing_price  median_listing_price_mm  \
# 764082  NaN              259950.0                      NaN
# ...

# %%
data_current = pd.read_csv('https://econdata.s3-us-west-2.amazonaws.com/Reports/Core/RDC_Inventory_Core_Metrics_Zip.csv')
# Out:
#   month_date_yyyymm  postal_code          zip_name flag  median_listing_price  \
# 0            202005      23901.0     farmville, va    *              249950.0
# 1            202005      19151.0  philadelphia, pa    *              165049.0
# 2            202005      33186.0         miami, fl  NaN              330050.0
# 3            202005      45429.0        dayton, oh    *              284950.0
# 4            202005      83014.0        wilson, wy  NaN             2750050.0
#
#    median_listing_price_mm  median_listing_price_yy  active_listing_count  \
# 0                   0.0200                   0.2346                  71.0
# 1                   0.1000                   0.0476                  23.0
# 2                  -0.0177                  -0.0075                 147.0
# 3                   0.0672                   0.5407                  31.0
# 4                  -0.0590                  -0.0833                  32.0
#
# ...

# %%
data_hotness = pd.read_csv('https://econdata.s3-us-west-2.amazonaws.com/Reports/Hotness/RDC_Inventory_Hotness_Metrics_Zip_History.csv')
# Out:
# 49

# %% [markdown]
# ## Stream Gage Data
# Loading Stream Gage data from USGS. Pre-sorted to only include those with more than 20 years of data

# %%
os.chdir('/Users/calvinwhealton/Documents/GitHub/tdi_capstone/peak_data')
gages = pd.read_csv('usgs_gages.txt',sep='\t',skiprows=20,dtype=str)
gages.head()
# Out:
#   agency_cd   site_no                                     station_nm\n
# 0      USGS  01010000       St. John River at Ninemile Bridge, Maine\n
# 1      USGS  01010070          Big Black River near Depot Mtn, Maine\n
# 2      USGS  01010500                St. John River at Dickey, Maine\n
# 3      USGS  01011000            Allagash River near Allagash, Maine\n
# 4      USGS  01011500  St. Francis River near Connors, New Brunswick\n

# %%
# Out:
# Index(['agency_cd', 'site_no', 'station_nm\n'], dtype='object')

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'station_nm\n'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-9bb8980921a1> in <module>
# ...
